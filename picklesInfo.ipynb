# %% [markdown]
# ## Read and check pickles

# %%
#%matplotlib notebook
# %matplotlib widget
import pandas as pd
import os 
import matplotlib.pyplot as plt
import numpy as np

# %%
path= '/home/mauricio/Documents/Pytorch/1st-place-kaggle-kuzushiji-recognition/data/'

# %%
#/home/mauricio/Documents/Pytorch/1st-place-kaggle-kuzushiji-recognition/data
df = pd.read_csv(path+'sample_submission.csv')
df.head()
# Out:
#   image_id                                             labels
# 0   test_1  U+9084 1370 191 64 50 U+9084 1140 320 62 43 U+...
# 1  test_24  U+5929 1501 198 48 46 U+5929 1491 406 61 41 U+...
# 2  test_53  U+52FF 1469 246 63 64 U+52FF 244 321 62 44 U+7...
# 3  test_75  U+5404 790 240 57 64 U+5404 389 858 55 20 U+6A...
# 4  test_48  U+53EA 1482 255 58 65 U+7576 1503 312 33 48 U+...

# %%
train = pd.read_pickle(path+'dtrain.pkl')
print(len(train))
train
# Out:
# 52
# [{'filename': '20220627_25.jpg',
#   'width': 1754,
#   'height': 1240,
#   'ann': {'bboxes': array([[ 712.,  238.,  779.,  303.],
#           [ 715.,  297.,  772.,  351.],
#           [ 729.,  349.,  773.,  406.],
#           [ 560.,  305.,  576.,  339.],
#           [ 566.,  931.,  609.,  975.],
#           [ 402.,  299.,  424.,  332.],
#           [ 270.,  237.,  324.,  270.],
#           [ 694.,  403.,  775.,  460.],
#           [ 626., 1044.,  704., 1090.],
#           [ 397.,  564.,  450.,  617.],
#           [ 710.,  463.,  813.,  524.],
#           [ 528.,  386.,  599.,  448.],
#           [ 727.,  556.,  805.,  611.],
#           [ 738.,  639.,  811.,  695.],
#           [ 753.,  698.,  784.,  723.],
#           [ 637.,  968.,  665.,  990.],
#           [ 736.,  729.,  801.,  781.],
#           [ 594.,  183.,  650.,  227.],
#           [ 600.,  236.,  642.,  275.],
#           [ 590.,  278.,  659.,  325.],
#           [ 604.,  329.,  651.,  364.],
# ...

# %%
val = pd.read_pickle(path+'dtrainval.pkl') #dval is empy??
print(len(val))
val
# Out:
# 52
# [{'filename': '20220627_25.jpg',
#   'width': 1754,
#   'height': 1240,
#   'ann': {'bboxes': array([[ 712.,  238.,  779.,  303.],
#           [ 715.,  297.,  772.,  351.],
#           [ 729.,  349.,  773.,  406.],
#           [ 560.,  305.,  576.,  339.],
#           [ 566.,  931.,  609.,  975.],
#           [ 402.,  299.,  424.,  332.],
#           [ 270.,  237.,  324.,  270.],
#           [ 694.,  403.,  775.,  460.],
#           [ 626., 1044.,  704., 1090.],
#           [ 397.,  564.,  450.,  617.],
#           [ 710.,  463.,  813.,  524.],
#           [ 528.,  386.,  599.,  448.],
#           [ 727.,  556.,  805.,  611.],
#           [ 738.,  639.,  811.,  695.],
#           [ 753.,  698.,  784.,  723.],
#           [ 637.,  968.,  665.,  990.],
#           [ 736.,  729.,  801.,  781.],
#           [ 594.,  183.,  650.,  227.],
#           [ 600.,  236.,  642.,  275.],
#           [ 590.,  278.,  659.,  325.],
#           [ 604.,  329.,  651.,  364.],
# ...

# %%
test = pd.read_pickle(path+'dtest.pkl')
print(len(test))
test
# Out:
# 22
# [{'filename': 'test_1.jpg',
#   'width': 1754,
#   'height': 1240,
#   'ann': {'bboxes': array([], shape=(0, 4), dtype=float32),
#    'labels': array([], dtype=int64),
#    'bboxes_ignore': array([], shape=(0, 4), dtype=float32),
#    'labels_ignore': array([], dtype=int64)}},
#  {'filename': 'test_24.jpg',
#   'width': 1754,
#   'height': 1240,
#   'ann': {'bboxes': array([], shape=(0, 4), dtype=float32),
#    'labels': array([], dtype=int64),
#    'bboxes_ignore': array([], shape=(0, 4), dtype=float32),
#    'labels_ignore': array([], dtype=int64)}},
#  {'filename': 'test_53.jpg',
#   'width': 1754,
#   'height': 1240,
#   'ann': {'bboxes': array([], shape=(0, 4), dtype=float32),
#    'labels': array([], dtype=int64),
#    'bboxes_ignore': array([], shape=(0, 4), dtype=float32),
#    'labels_ignore': array([], dtype=int64)}},
#  {'filename': 'test_75.jpg',
#   'width': 1754,
#   'height': 1240,
#   'ann': {'bboxes': array([], shape=(0, 4), dtype=float32),
# ...

# %%
train_crop = pd.read_pickle(path+'dtrain_crop.pkl')
print(len(train_crop))
train_crop
# Out:
# 136
# [{'filename': '20220627_25_0.png',
#   'width': 1024,
#   'height': 1024,
#   'ann': {'bboxes': array([[153., 121., 220., 186.],
#           [156., 180., 213., 234.],
#           [170., 232., 214., 289.],
#           [  1., 188.,  17., 222.],
#           [  7., 814.,  50., 858.],
#           [135., 286., 216., 343.],
#           [ 67., 927., 145., 973.],
#           [151., 346., 254., 407.],
#           [168., 439., 246., 494.],
#           [179., 522., 252., 578.],
#           [194., 581., 225., 606.],
#           [ 78., 851., 106., 873.],
#           [177., 612., 242., 664.],
#           [ 35.,  66.,  91., 110.],
#           [ 41., 119.,  83., 158.],
#           [ 31., 161., 100., 208.],
#           [ 45., 212.,  92., 247.],
#           [ 26., 249., 106., 303.],
#           [ 43., 297., 103., 348.],
#           [ 51., 349., 104., 427.],
#           [ 53., 428., 107., 477.],
#           [ 58., 482., 103., 543.],
#           [ 60., 543., 102., 574.],
# ...

# %%
for i in train_crop:
    print(i['ann']['bboxes_ignore'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
